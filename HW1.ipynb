# %% [markdown]
# <a href="https://colab.research.google.com/github/PakYuHwan/prac_class/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.4
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages('nycflights13')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(nycflights13)

# %%
head(flights)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
flights%>%summary()
# Out:
#       year          month             day           dep_time    sched_dep_time
#  Min.   :2013   Min.   : 1.000   Min.   : 1.00   Min.   :   1   Min.   : 106
#  1st Qu.:2013   1st Qu.: 4.000   1st Qu.: 8.00   1st Qu.: 907   1st Qu.: 906
#  Median :2013   Median : 7.000   Median :16.00   Median :1401   Median :1359
#  Mean   :2013   Mean   : 6.549   Mean   :15.71   Mean   :1349   Mean   :1344
#  3rd Qu.:2013   3rd Qu.:10.000   3rd Qu.:23.00   3rd Qu.:1744   3rd Qu.:1729
#  Max.   :2013   Max.   :12.000   Max.   :31.00   Max.   :2400   Max.   :2359
#                                                  NA's   :8255
#    dep_delay          arr_time    sched_arr_time   arr_delay
#  Min.   : -43.00   Min.   :   1   Min.   :   1   Min.   : -86.000
#  1st Qu.:  -5.00   1st Qu.:1104   1st Qu.:1124   1st Qu.: -17.000
#  Median :  -2.00   Median :1535   Median :1556   Median :  -5.000
#  Mean   :  12.64   Mean   :1502   Mean   :1536   Mean   :   6.895
# ...

# %%
flights%>%colnames()
# Out:
#  [1] "year"           "month"          "day"            "dep_time"
#  [5] "sched_dep_time" "dep_delay"      "arr_time"       "sched_arr_time"
#  [9] "arr_delay"      "carrier"        "flight"         "tailnum"
# [13] "origin"         "dest"           "air_time"       "distance"
# [17] "hour"           "minute"         "time_hour"

# %%
filter(flights,year==2013,month==10,day==1) %>%filter(dest=='CLT')%>%head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 10    1   447      500            -13       614      648
# 2 2013 10    1   606      615             -9       744      811
# 3 2013 10    1   608      615             -7       738      813
# 4 2013 10    1   612      615             -3       808      821
# 5 2013 10    1   626      635             -9       818      833
# 6 2013 10    1   629      630             -1       807      840
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -34       US      1877   N538UW  EWR    CLT  69       529      5     0
# 2 -27       US      1772   N539UW  JFK    CLT  70       541      6    15
# 3 -35       US       840   N108UW  EWR    CLT  67       529      6    15
# 4 -13       EV      4471   N13965  EWR    CLT  75       529      6    15
# 5 -15       US      2023   N171US  EWR    CLT  72       529      6    35
# ...

# %%
flights%>% filter(year==2013 &  month==1 & day==1 & dest %in% c('CLT','ORD'))%>%head(3)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   554      558            -4        740      728
# 2 2013 1     1   558      600            -2        753      745
# 3 2013 1     1   608      600             8        807      735
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 12        UA      1696   N39463  EWR    ORD  150      719      5    58
# 2  8        AA       301   N3ALAA  LGA    ORD  138      733      6     0
# 3 32        MQ      3768   N9EAMQ  EWR    ORD  139      719      6     0
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 06:00:00
# 3 2013-01-01 06:00:00

# %%
arrange(flights,dep_delay)%>%head(3)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 12     7  2040     2123           -43         40     2352
# 2 2013  2     3  2022     2055           -33       2240     2338
# 3 2013 11    10  1408     1440           -32       1549     1559
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  48       B6        97   N592JB  JFK    DEN  265      1626     21   23
# 2 -58       DL      1715   N612DL  LGA    MSY  162      1183     20   55
# 3 -10       EV      5713   N825AS  LGA    IAD   52       229     14   40
#   time_hour
# 1 2013-12-07 21:00:00
# 2 2013-02-03 20:00:00
# 3 2013-11-10 14:00:00

# %%
select(flights,year,month,dep_delay,arr_delay)%>%head()
# Out:
#   year month dep_delay arr_delay
# 1 2013 1      2         11
# 2 2013 1      4         20
# 3 2013 1      2         33
# 4 2013 1     -1        -18
# 5 2013 1     -6        -25
# 6 2013 1     -4         12

# %%
select(flights,year:arr_delay)%>%head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay
# 1  11
# 2  20
# 3  33
# 4 -18
# 5 -25
# 6  12

# %%
rename(flights,departdelay=dep_delay,arrivaldelay=arr_delay)%>%head()
# Out:
#   year month day dep_time sched_dep_time departdelay arr_time sched_arr_time
# 1 2013 1     1   517      515             2           830      819
# 2 2013 1     1   533      529             4           850      830
# 3 2013 1     1   542      540             2           923      850
# 4 2013 1     1   544      545            -1          1004     1022
# 5 2013 1     1   554      600            -6           812      837
# 6 2013 1     1   554      558            -4           740      728
#   arrivaldelay carrier flight tailnum origin dest air_time distance hour minute
# 1  11          UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20          UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33          AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18          B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25          DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
head(flights)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
flights%>%select(,air_time,ends_with("delay"))%>%mutate(gain=dep_delay-arr_delay, hours=air_time/60, gain_per_hour=gain/hours)%>%head()
# Out:
#   air_time dep_delay arr_delay gain hours    gain_per_hour
# 1 227       2         11        -9  3.783333  -2.378855
# 2 227       4         20       -16  3.783333  -4.229075
# 3 160       2         33       -31  2.666667 -11.625000
# 4 183      -1        -18        17  3.050000   5.573770
# 5 116      -6        -25        19  1.933333   9.827586
# 6 150      -4         12       -16  2.500000  -6.400000

# %%
flights%>%group_by(dest)%>%summarise(delay=mean(dep_delay,na.rm=T),delay_sd=sd(dep_delay,na.rm=TRUE))%>%head()
# Out:
#   dest delay     delay_sd
# 1 ABQ  13.740157 30.52601
# 2 ACK   6.456604 26.32027
# 3 ALB  23.620525 48.55768
# 4 ANC  12.875000 25.59262
# 5 ATL  12.509824 43.84730
# 6 AUS  13.025641 36.70737

# %%
flights%>%ggplot(mapping=aes(x=arr_delay,y=dep_delay))+theme_bw()+geom_point(alpha=1/4)+geom_smooth()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
#
# Warning message:
# “Removed 9430 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 9430 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(data=flights)+theme_bw()+
geom_point(mapping=aes(x=arr_delay,y=dep_delay))+
theme(axis.line=element_line(size=5,colour="black"),
  panel.grid.minor=element_blank(),
  panel.border=element_blank(),
  text=element_text(size=25))
# Out:
# Warning message:
# “Removed 9430 rows containing missing values (geom_point).”
# plot without title
